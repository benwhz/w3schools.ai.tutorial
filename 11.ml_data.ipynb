# %% [markdown]
# # 11. 机器学习中的数据
#
# - [11.1 什么是数据？](#1)
# - [11.2 人工智能需要数据](#2)
# - [11.3 数据存储](#3)
# - [11.4 定量和定性数据](#4)
# - [11.5 普查与抽样](#5)
# - [11.6 大数据](#6)
# - [11.7 数据挖掘](#7)
#
# <a name='1'></a>
# ## 11.1 什么是数据？
#
# 数据可以有多种类型的，对于机器学习来说，数据是事实的集合：
#
# |数据类型|数据说明|
# |:--|:--:|
# |数字|价格、日期等|
# |测量值|尺寸，重量等|
# |文字|姓名、地址、内容等|
# |观测|统计汽车数量|
# |语言描述|今天很热|
#
# <a name='2'></a>
# ## 11.2 人工智能需要数据
#
# 就像房地产经纪人需要有关已售房屋的数据来估算价格，人工智能也需要数据：
#
# - 机器学习程序需要数据来估算价格。
#
# - 数据可以帮助我们观察和理解。
#
# - 数据可以帮助我们找到新的机会。
#
# - 数据可以帮助我们解决误解。
#
# **医疗保健**：
# 医疗保健和生命科学收集公共卫生数据和患者数据，以了解如何改善患者护理并挽救生命。
#
# **商业**：
# 许多行业中最成功的公司都是数据驱动的。他们使用复杂的数据分析来了解公司如何表现更好。
#
# **金融**：
# 银行和保险公司收集和评估有关客户、贷款和存款的数据，以支持战略决策。
#
# <a name='3'></a>
# ## 11.3 数据存储
#
# 最常收集的数据是数字和测量值，数据通常存储在表示值之间关系的数组中。
#
# 例如下表包含了房价与面积之间的关系：
#
# |房价|	7|	8|	8|	9|	9|	9|	10|	11|	14|	14|	15|
# |--|--|--|--|--|--|--|--|--|--|--|--|
# |面积|	50|	60|	70|	80|	90|	100|	110|	120|	130|	140|	150|
#
# <a name='4'></a>
# ## 11.4 定量与定性数据
#
# 定量数据就是数字：
#
# - 55 辆车
# - 15 米
# - 35 名儿童
#
# 定性数据是描述性的：
#
# - 天气很冷
# - 路程很长
# - 很有趣
#
# <a name='5'></a>
# ## 11.5 普查或抽样
#
# 人口普查就是我们为一个群体的每个成员收集数据，样本就是我们为一个群体的某些成员收集数据。
#
# 如果我们想知道中国有多少人吸烟，我们可以询问每个人（人口普查），也可以随机询问 10,000 人（样本）。
#
# 人口普查是准确的，但很难做到。样本是不准确的，但更容易做到。
#
# **抽样术语**
#
# 总体是一群我们想要收集信息的个体（对象）。
#
# 人口普查是关于总体中每个人的信息。
#
# 样本是关于一部分总体的信息（为了代表所有人）。
#
# **随机样本**
#
# 为了使样本能够代表总体，必须随机收集样本。
#
# 随机样本是总体中每个成员都有同等机会出现在样本中的样本。
#
# **抽样偏差**
#
# 当样本的收集方式导致某些个体不太可能（或更有可能）被纳入样本时，就会发生抽样偏差（误差）。
#
# <a name='6'></a>
# ## 11.6 大数据
# 大数据（英语：big data；亦称作巨量资料），指的是传统数据处理应用软件不足以处理的大或复杂的数据集的形容术语。大数据也可以定义为来自各种来源的大量非结构化或结构化数据。从学术角度而言，大数据的出现促成广泛主题的新颖研究。这也导致各种大数据统计方法的发展。大数据并没有统计学的抽样方法；它只是观察和追踪发生的事情。
#
# <a name='7'></a>
# ## 11.7 数据挖掘
# 数据挖掘（英語：Data mining）是一个跨学科的计算机科学分支。它是用人工智能、机器学习、统计学和数据库的交叉方法在相对较大型的数据集中发现模式的计算过程。数据挖掘过程的总体目标是从一个数据集中提取信息，并将其转换成可理解的结构，以进一步使用。
